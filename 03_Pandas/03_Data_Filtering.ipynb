# %%
import pandas as pd

# %%
# %pip install openpyxl
# Out:
# ...
#      ------------------------------------ 250.9/250.9 kB 615.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel("ins.xlsx")

# %%
df
# Out:
#     S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1       2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2       3 2019-09-10  Central  Timothy      David    Television    7.0
# 3       4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4       5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7       8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8       9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9      10 2018-04-18      NaN   Martha     Steven    Television   75.0
# 10     11 2018-05-05  Central  Hermann        NaN    Television   90.0
# 11     12 2018-05-22     West  Douglas    Michael    Television   32.0
# ...

# %%
df.head()
# Out:
#    S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0      1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1      2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2      3 2019-09-10  Central  Timothy      David    Television    7.0
# 3      4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4      5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
#
#    Unit_price  Sale_amt
# 0        58.5    2457.0
# 1       125.0     375.0
# 2      1198.0    8386.0
# 3      1198.0  113810.0
# 4       500.0   25000.0

# %% [markdown]
# # Filtering Unique Values

# %%
df.Region.unique()
# Out:
# array(['Central', 'West', 'East', nan], dtype=object)

# %%
df.Manager.unique()
# Out:
# array(['Hermann', 'Timothy', 'Martha', nan, 'Douglas'], dtype=object)

# %%
df.SalesMan.unique()
# Out:
# array(['Shelli', 'Stephen', 'David', 'Alexander', 'Luis', 'Steven', nan,
#        'Michael', 'Sigal', 'Diana', 'Karen', 'John'], dtype=object)

# %%
df.Item.unique()
# Out:
# array(['Video Games', 'Desk', 'Television', 'Home Theater', 'Cell Phone',
#        nan], dtype=object)

# %% [markdown]
# ### All Sales From Central

# %%
df[df.Region == "Central"]
# Out:
#     S.No.  OrderDate   Region  Manager SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann   Shelli   Video Games   42.0
# 2       3 2019-09-10  Central  Timothy    David    Television    7.0
# 4       5 2018-01-23  Central  Hermann   Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann     Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN    David    Cell Phone   27.0
# 10     11 2018-05-05  Central  Hermann      NaN    Television   90.0
# 13     14 2018-06-25  Central  Hermann    Sigal    Television   90.0
# 17     18 2018-09-01  Central  Douglas     John          Desk    2.0
# 19     20 2018-10-05  Central  Hermann    Sigal  Home Theater   28.0
# 22     23 2018-11-25  Central  Hermann   Shelli   Video Games   96.0
# 23     24 2018-12-12  Central  Douglas     John    Television   67.0
# 25     26 2019-01-15  Central  Timothy    David  Home Theater   46.0
# 26     27 2019-02-01  Central  Douglas     John  Home Theater   87.0
# ...

# %%
df
# Out:
#     S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1       2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2       3 2019-09-10  Central  Timothy      David    Television    7.0
# 3       4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4       5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7       8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8       9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9      10 2018-04-18      NaN   Martha     Steven    Television   75.0
# 10     11 2018-05-05  Central  Hermann        NaN    Television   90.0
# 11     12 2018-05-22     West  Douglas    Michael    Television   32.0
# ...

# %% [markdown]
# # Total Sales from West

# %%
df[df.Region == "East"]["Sale_amt"].sum()
# Out:
# Empty DataFrame
# Columns: [S.No., OrderDate, Region, Manager, SalesMan, Item, Units, Unit_price, Sale_amt]
# Index: []

# %% [markdown]
# # Total Television Sales in East:

# %%
df[(df.Region == "East")&(df.Item == "Television")]
# Out:
#    S.No.  OrderDate Region Manager   SalesMan        Item  Units  Unit_price  \
# 3      4 2018-01-06   East  Martha  Alexander  Television   95.0      1198.0
#
#    Sale_amt
# 3  113810.0

# %%
df.head()
# Out:
#    S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0      1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1      2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2      3 2019-09-10  Central  Timothy      David    Television    7.0
# 3      4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4      5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
#
#    Unit_price  Sale_amt
# 0        58.5    2457.0
# 1       125.0     375.0
# 2      1198.0    8386.0
# 3      1198.0  113810.0
# 4       500.0   25000.0

# %% [markdown]
# ### Number of cellphones sold by alexander in central

# %%
df[(df.Region == "Central")&(df.SalesMan == "David")&(df.Item == "Cell Phone")]
# Out:
#    S.No.  OrderDate   Region Manager SalesMan        Item  Units  Unit_price  \
# 6      7 2018-02-26  Central     NaN    David  Cell Phone   27.0       225.0
#
#    Sale_amt
# 6    6075.0

# %% [markdown]
# ## John and Diana Total sales of video games in central

# %%
df[(df.Region == "Central")&(df.SalesMan.isin(["Diana","John"]))&(df.Item == "Video Games")]
# Out:
# Empty DataFrame
# Columns: [S.No., OrderDate, Region, Manager, SalesMan, Item, Units, Unit_price, Sale_amt]
# Index: []

# %%
df[(df.Region == "Central")&(df.SalesMan == "John") | (df.SalesMan == "Alexander")&(df.Item == "Video Games")]
# Out:
#     S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 17     18 2018-09-01  Central  Douglas       John          Desk    2.0
# 18     19 2018-09-18     East   Martha  Alexander   Video Games   16.0
# 23     24 2018-12-12  Central  Douglas       John    Television   67.0
# 26     27 2019-02-01  Central  Douglas       John  Home Theater   87.0
# 35     36 2019-07-04     East   Martha  Alexander   Video Games    NaN
# 47     48 2019-02-01  Central  Douglas       John  Home Theater   87.0
#
#     Unit_price  Sale_amt
# 17       125.0     250.0
# 18        58.5     936.0
# 23      1198.0   80266.0
# 26       500.0   43500.0
# 35        58.5       0.0
# 47       500.0   43500.0

# %%
df[(df.Region == "Central")&(df.SalesMan == "John")]
# Out:
#     S.No.  OrderDate   Region  Manager SalesMan          Item  Units  \
# 17     18 2018-09-01  Central  Douglas     John          Desk    2.0
# 23     24 2018-12-12  Central  Douglas     John    Television   67.0
# 26     27 2019-02-01  Central  Douglas     John  Home Theater   87.0
# 47     48 2019-02-01  Central  Douglas     John  Home Theater   87.0
#
#     Unit_price  Sale_amt
# 17       125.0     250.0
# 23      1198.0   80266.0
# 26       500.0   43500.0
# 47       500.0   43500.0

# %%
df
# Out:
#     S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1       2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2       3 2019-09-10  Central  Timothy      David    Television    7.0
# 3       4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4       5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7       8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8       9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9      10 2018-04-18      NaN   Martha     Steven    Television   75.0
# 10     11 2018-05-05  Central  Hermann        NaN    Television   90.0
# 11     12 2018-05-22     West  Douglas    Michael    Television   32.0
# ...

# %%
df.head()
# Out:
#    S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0      1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1      2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2      3 2019-09-10  Central  Timothy      David    Television    7.0
# 3      4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4      5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
#
#    Unit_price  Sale_amt
# 0        58.5    2457.0
# 1       125.0     375.0
# 2      1198.0    8386.0
# 3      1198.0  113810.0
# 4       500.0   25000.0

# %%
df.groupby('Region')['Sale_amt'].sum()
# Out:
# Region
# Central    860681.5
# East       320080.0
# West        88186.0
# Name: Sale_amt, dtype: float64

# %%
df.groupby("Item")["Sale_amt"].sum()
# Out:
# Item
# Cell Phone      105750.0
# Desk              1625.0
# Home Theater    404500.0
# Television      820630.0
# Video Games      20533.5
# Name: Sale_amt, dtype: float64

# %% [markdown]
# ## Find The Top 3 WORST SalesMan According to their Sales Amount

# %%
df.groupby("SalesMan")["Sale_amt"].sum().sort_values().head(3)
# Out:
# SalesMan
# Stephen    21350.0
# Shelli     33698.0
# Karen      48204.0
# Name: Sale_amt, dtype: float64

# %%
b = df.groupby("SalesMan")["Sale_amt"].sum().sort_values()
b.iloc[[0,1,2]]
# Out:
# SalesMan
# Stephen    21350.0
# Shelli     33698.0
# Karen      48204.0
# Name: Sale_amt, dtype: float64

# %%
df.groupby("SalesMan")["Sale_amt"].agg(["sum","mean","median"])
# Out:
#                 sum          mean   median
# SalesMan
# Alexander  233076.0  29134.500000  22200.0
# David      212835.0  30405.000000  23000.0
# Diana       79300.0  19825.000000  21600.0
# John       167516.0  41879.000000  43500.0
# Karen       48204.0  16068.000000   4329.0
# Luis       101478.0  20295.600000   5500.0
# Michael     66836.0  33418.000000  33418.0
# Shelli      33698.0   8424.500000   4036.5
# Sigal      125037.5  41679.166667  14000.0
# Stephen     21350.0   4270.000000    375.0
# Steven     199690.0  39938.000000  16772.0

# %%
df.head(10)
# Out:
#    S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0      1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1      2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2      3 2019-09-10  Central  Timothy      David    Television    7.0
# 3      4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4      5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5      6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6      7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7      8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8      9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9     10 2018-04-18      NaN   Martha     Steven    Television   75.0
#
#    Unit_price  Sale_amt
# 0        58.5    2457.0
# 1       125.0     375.0
# 2      1198.0    8386.0
# 3      1198.0  113810.0
# 4       500.0   25000.0
# 5      1198.0   43128.0
# ...

# %%
df[df.SalesMan == "David"]
# Out:
#     S.No.  OrderDate   Region  Manager SalesMan          Item  Units  \
# 2       3 2019-09-10  Central  Timothy    David    Television    7.0
# 6       7 2018-02-26  Central      NaN    David    Cell Phone   27.0
# 25     26 2019-01-15  Central  Timothy    David  Home Theater   46.0
# 32     33 2019-05-14  Central  Timothy    David    Television   53.0
# 33     34 2019-05-31  Central  Timothy    David  Home Theater   80.0
# 39     40 2019-09-10  Central  Timothy    David    Television    7.0
# 51     52 2019-05-14  Central  Timothy    David    Television   53.0
#
#     Unit_price  Sale_amt
# 2       1198.0    8386.0
# 6        225.0    6075.0
# 25       500.0   23000.0
# 32      1198.0   63494.0
# 33       500.0   40000.0
# 39      1198.0    8386.0
# 51      1198.0   63494.0

# %% [markdown]
# ### region wise avg salesman items sold

# %%
df.groupby(["Region","SalesMan","Item"])["Units"].agg(['mean',"sum"])
# Out:
#                                      mean    sum
# Region  SalesMan  Item
# Central David     Cell Phone    27.000000   27.0
#                   Home Theater  63.000000  126.0
#                   Television    30.000000  120.0
#         John      Desk           2.000000    2.0
#                   Home Theater  87.000000  174.0
#                   Television    67.000000   67.0
#         Luis      Home Theater  52.500000  105.0
#                   Television    36.000000   36.0
#                   Video Games   50.000000  100.0
#         Shelli    Desk           5.000000    5.0
#                   Home Theater  50.000000   50.0
#                   Video Games   69.000000  138.0
#         Sigal     Home Theater  28.000000   28.0
#                   Television    90.000000   90.0
#                   Video Games   55.000000   55.0
#         Steven    Home Theater  28.000000   28.0
#                   Television    40.000000   80.0
# East    Alexander Cell Phone    64.000000   64.0
# ...

# %%
df.head(10)
# Out:
#    S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0      1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1      2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2      3 2019-09-10  Central  Timothy      David    Television    7.0
# 3      4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4      5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5      6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6      7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7      8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8      9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9     10 2018-04-18      NaN   Martha     Steven    Television   75.0
#
#    Unit_price  Sale_amt
# 0        58.5    2457.0
# 1       125.0     375.0
# 2      1198.0    8386.0
# 3      1198.0  113810.0
# 4       500.0   25000.0
# 5      1198.0   43128.0
# ...

# %%
df[df.SalesMan == "David"]
# Out:
#     S.No.  OrderDate   Region  Manager SalesMan          Item  Units  \
# 2       3 2019-09-10  Central  Timothy    David    Television    7.0
# 6       7 2018-02-26  Central      NaN    David    Cell Phone   27.0
# 25     26 2019-01-15  Central  Timothy    David  Home Theater   46.0
# 32     33 2019-05-14  Central  Timothy    David    Television   53.0
# 33     34 2019-05-31  Central  Timothy    David  Home Theater   80.0
# 39     40 2019-09-10  Central  Timothy    David    Television    7.0
# 51     52 2019-05-14  Central  Timothy    David    Television   53.0
#
#     Unit_price  Sale_amt
# 2       1198.0    8386.0
# 6        225.0    6075.0
# 25       500.0   23000.0
# 32      1198.0   63494.0
# 33       500.0   40000.0
# 39      1198.0    8386.0
# 51      1198.0   63494.0
