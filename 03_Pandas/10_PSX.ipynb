# %% [markdown]
# # **Getting Pakistan Stock Exchange Data**

# %%
# %pip install psxdata
# %pip install psx-data-reader
# Out:
# ...
#   Using cached psx_data_reader-0.0.6-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached tqdm-4.69.0-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached soupsieve-2.8.4-py3-none-any.whl.metadata (4.6 kB)
# ...
#      ---------------------------------------- 0.0/42.5 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.5 kB 330.3 kB/s eta 0:00:01
#      --------------------------- ---------- 30.7/42.5 kB 330.3 kB/s eta 0:00:01
#      --------------------------- ---------- 30.7/42.5 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 42.5/42.5 kB 230.5 kB/s eta 0:00:00
# ...
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
# Using cached psx_data_reader-0.0.6-py3-none-any.whl (6.4 kB)
# ...

# %%
import psx
from psx import stocks, tickers
from psx.web import data_reader

# %%
import datetime
from datetime import datetime

# %%
tickers = tickers()

# %%
tickers
# Out:
#          symbol                             name  \
# 0      AKBLTFC6                Askari Bank(TFC6)
# 1      BAFLTFC6               Bank Al-Falah(TFC6
# 2      BAFLTFC8               Bank Alfalah(TFC8)
# 3     BAHLTFC10  BANK AL HABIB LTD. (10TH ISSUE)
# 4      BAHLTFC9               Bank Al-Habib(TFC9
# ...         ...                              ...
# 1075       ZELP  Zeal Pak Cement Factory Limited
# 1076       ZHCM       Zahur Cotton Mills Limited
# 1077        ZIL                      ZIL Limited
# 1078        ZTL          Zephyr Textiles Limited
# 1079       ZUMA           Zuma Resources Limited
#
#                          sectorName  isETF  isDebt  isGEM
# 0                   BILLS AND BONDS  False    True    NaN
# 1                   BILLS AND BONDS  False    True    NaN
# 2                   BILLS AND BONDS  False    True    NaN
# 3                   BILLS AND BONDS  False    True    NaN
# 4                   BILLS AND BONDS  False    True    NaN
# ...

# %%
tickers.name.value_counts()
# Out:
# name
#                                    15
# TPL Properties Limited              2
# Chakwal Spinning Mills Limited      2
# Ghani Global(R)                     2
# Waves Home Appliances Limited       2
#                                    ..
# Zeal Pak Cement Factory Limited     1
# Zahur Cotton Mills Limited          1
# ZIL Limited                         1
# Zephyr Textiles Limited             1
# Zuma Resources Limited              1
# Name: count, Length: 1062, dtype: int64

# %%
tickers.name == "MEBL"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1075    False
# 1076    False
# 1077    False
# 1078    False
# 1079    False
# Name: name, Length: 1080, dtype: bool

# %%
type(tickers)
# Out:
# pandas.DataFrame

# %%
from datetime import date

# %%
start = date(2025, 1, 1)
end = date(2026, 7, 17)

# %%
data = psx.stocks("HBL", start=start, end=end )
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3540\657575911.py in ?()
# ----> 1 data = psx.stocks("HBL", start=start, end=end )
#
# c:\Users\SMIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\psx\web.py in ?(self, tickers, start, end)
#      50     def stocks(self, tickers: Union[str, list], start: date, end: date) -> container:
#      51         tickers = [tickers] if isinstance(tickers, str) else tickers
#      52         dates = self.daterange(start, end)
#      53
# ---> 54         data = [self.get_psx_data(ticker, dates)[start: end] for ticker in tickers]
#      55
#      56         if len(data) == 1:
#      57             return data[0]
#
# c:\Users\SMIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\psx\web.py in ?(.0)
# ---> 54     def stocks(self, tickers: Union[str, list], start: date, end: date) -> container:
# ...
